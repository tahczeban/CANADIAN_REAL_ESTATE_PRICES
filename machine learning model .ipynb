# %%
# %matplotlib inline
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.preprocessing as preproc
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Preprocess

# %%
# Import data from database and set index on the first column
house_df = pd.read_csv('Resources/mockdata.csv',index_col=0)
house_df.head()
# Out:
#                             Year  Household Income     CRIM  \
# Province
# Alberta                     2015          108594.0  8916.56
# British Columbia            2015           79234.0  8608.09
# Manitoba                    2015           72971.0  8925.91
# New Brunswick               2015           63767.0  5478.74
# Newfoundland and Labrador   2015           75183.0  6370.75
#
#                            flowgreenhouse_emmissions Provincial Population  \
# Province
# Alberta                                      278,925            16,548,357
# British Columbia                              80,171            19,082,570
# Manitoba                                      20,876             5,164,103
# New Brunswick                                 17,835             3,037,185
# Newfoundland and Labrador                     11,299             2,113,237
#
#                             number of college  House price
# Province
# Alberta                                    52        432.8
# ...

# %%
house_df
# Out:
#                             Year  Household Income       CRIM  \
# Province
# Alberta                     2015          108594.0    8916.56
# British Columbia            2015           79234.0    8608.09
# Manitoba                    2015           72971.0    8925.91
# New Brunswick               2015           63767.0    5478.74
# Newfoundland and Labrador   2015           75183.0    6370.75
# Nova Scotia                 2015           64717.0    5727.24
# Ontario                     2015           79674.0    4021.58
# Prince Edward Island        2015           63660.0    4750.04
# Quebec                      2015           61161.0    4252.49
# Saskatchewan                2015           83814.0  12,919.20
#
#                            flowgreenhouse_emmissions Provincial Population  \
# Province
# Alberta                                      278,925            16,548,357
# British Columbia                              80,171            19,082,570
# ...

# %%
# check null value and data type.
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Alberta  to Saskatchewan
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       10 non-null     int64
#  1   Household Income           10 non-null     float64
#  2   CRIM                       10 non-null     object
#  3   flowgreenhouse_emmissions  10 non-null     object
#  4   Provincial Population      10 non-null     object
#  5   number of college          10 non-null     int64
#  6   House price                10 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 640.0+ bytes

# %%
house_df.describe()
# Out:
#          Year  Household Income  number of college  House price
# count    10.0         10.000000          10.000000     10.00000
# mean   2015.0      75277.500000          65.000000    337.86000
# std       0.0      14147.754555          81.559794    127.34809
# min    2015.0      61161.000000           4.000000    199.80000
# 25%    2015.0      64004.500000          14.000000    262.82500
# 50%    2015.0      74077.000000          32.000000    302.55000
# 75%    2015.0      79564.000000          60.250000    407.75000
# max    2015.0     108594.000000         229.000000    610.00000

# %%
# change the data type
# house_df["Household_Income","flowgreenhouse_emmissions","Provincial_Population"].astype(dtype='float')

# %%
# house_df.hist(bins=50,figsize=(20,15))
# plt.show()

# %%
# house_df.drop('province',axis=1)
#X = pd.get_dummies(house_df.drop("House price", axis=1))
#y  = house_df["House price"]
#X.describe()

# %%
# Creating the scaler instance
from sklearn.preprocessing import MinMaxScaler
data_scaler = MinMaxScaler()

# %%
# Fitting the scaler （divide）

# %%
# create correlation matrix 
corr_matrix=house_df.corr()
corr_matrix["House price"].sort_values(ascending=False)
# Out:
# House price          1.000000
# Household Income     0.573413
# number of college    0.346018
# Year                      NaN
# Name: House price, dtype: float64

# %%
plt.scatter(house_df['flowgreenhouse_emmissions'], house_df['House Price'], color='red')
plt.title('flowgreenhouse_emmissions Vs House Price', fontsize=14)
plt.xlabel('flowgreenhouse_emmissions', fontsize=14)
plt.ylabel('House Price', fontsize=14)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'House Price'
#
# The above exception was the direct cause of the following exception:
#
# ...
